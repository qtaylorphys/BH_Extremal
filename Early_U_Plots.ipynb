# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy.optimize import curve_fit
from scipy.stats import linregress
import re
#import pandas as pd
from scipy import special
plt.rcParams['axes.facecolor']='white'
plt.rcParams['savefig.facecolor']='white'

# %% [markdown]
# # $t_i$ vs $n_i/T_i^3$

# %% [markdown]
# Data taken from Mathematica

# %%
time = np.array((10**-22, 10**-19, 10**-16, 10**-13, 10**-10, 10**-7, 10**-4, 10**-3))
temp = np.array((3.82507*10**-12, 1.20959*10**-13, 3.82507*10**-15, 1.20959*10**-16, \
3.82507*10**-18, 1.20959*10**-19, 3.82507*10**-21, 1.20959*10**-22))
#masses
m11 = np.array((1.76086*10**-52, 1.76086*10**-58, 1.76086*10**-64, 1.76087*10**-70, \
1.76097*10**-76, 1.86111*10**-82, 1.9136*10**-87, 6.0257*10**-92))
m5e12 = np.array((6.2256*10**-50, 6.2256*10**-56, 6.2256*10**-62, 6.2256*10**-68, \
6.2256*10**-74, 6.2256*10**-80, 6.22851*10**-86, 8.66411*10**-92))
m12 = np.array((5.56834*10**-51, 5.56834*10**-57, 5.56834*10**-63, 5.56834*10**-69, \
5.56834*10**-75, 5.56867*10**-81, 5.88535*10**-87, 6.05135*10**-92))
m10 = np.array((5.56834*10**-54, 5.56834*10**-60, 5.56834*10**-66, 5.56867*10**-72, \
5.88535*10**-78, 6.05135*10**-83, 1.90549*10**-87, 6.02568*10**-92))
m9 = np.array((1.76086*10**-55, 1.76087*10**-61, 1.76097*10**-67, 1.86111*10**-73, \
1.9136*10**-78, 6.0257*10**-83, 1.90549*10**-87, 6.02568*10**-92))

# %%
plt.plot(np.log10(time), np.log10(m11/temp**3), color = "tab:blue", label = "$10^{11} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m5e12/temp**3), color = "tab:red", label = "$5e^{12} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m12/temp**3), color = "tab:green", label = "$10^{12} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m10/temp**3), color = "tab:purple", label = "$10^{10} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m9/temp**3), color = "yellow", label = "$10^{10} M_{Pl}$")
plt.xlabel("$Log_{10}(t_i/1s)$")
plt.ylabel("$Log_{10}(n_i/T_i^3)$")
plt.title("$n_i / T_i^3$")
plt.legend()
plt.show()

# %%
plt.plot(np.log10(time), np.log10(m11/temp**4), color = "tab:blue", label = "$10^{11} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m5e12/temp**4), color = "tab:red", label = "$5e^{12} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m12/temp**4), color = "tab:green", label = "$10^{12} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m10/temp**4), color = "tab:purple", label = "$10^{10} M_{Pl}$")
plt.plot(np.log10(time), np.log10(m9/temp**4), color = "yellow", label = "$10^{10} M_{Pl}$")
plt.xlabel("$Log_{10}(t_i/1s)$")
plt.ylabel("$Log_{10}(n_i/T_i^3)$")
plt.title("$n_i / T_i^4$")
plt.legend()
plt.show()
